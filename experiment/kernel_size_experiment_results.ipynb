# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

kernel_sizes = [3,5,7]
x = []
y = []
yerr = []
for size in kernel_sizes:
    file_name = f"../results/net_2conv_2fc_kernel_{size}.csv"
    df = pd.read_csv(file_name)
    mean = df["accuracy"].mean()
    std = df["accuracy"].std()
    x.append(size)
    y.append(mean)
    yerr.append(std*3) # three sigmas
fig = plt.figure()
plt.errorbar(x, y, yerr=yerr, fmt='o')
plt.ylabel("Accuracy")
plt.xlabel("Kernel size")
plt.title("Accuracy witch respect to kernel size")
# Out:
# Text(0.5, 1.0, 'Accuracy witch respect to kernel size')
